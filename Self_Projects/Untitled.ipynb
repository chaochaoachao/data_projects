# %%
# for data processing
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# for data visulization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style
matplotlib.style.use('classic')

sns.set_style('whitegrid')
# %matplotlib inline

# %%
# for reading stock data from yahoo
import pandas_datareader as pdr

# for time
from datetime import datetime

# %%
#for division
from __future__ import division

# %%
#a company list to analyze
tech_company_list=['APPL','GOOGL','MSFT','AMZN']

#set up end time and start time would be 1 year before to grab data
end = datetime.now().date()
start=datetime(end.year-1,end.month,end.day).date()
end
# Out:
# datetime.date(2019, 10, 7)

# %%
start
company = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB']

# %%
data=pdr.get_data_yahoo(company, start = start, end = end)

# %%
data.head()
# Out:
# Attributes        High                                                    \
# Symbols           AAPL         AMZN          FB         GOOG        MSFT
# Date
# 2018-10-08  224.800003  1902.000000  158.339996  1168.000000  112.029999
# 2018-10-09  227.270004  1896.680054  160.589996  1154.349976  113.080002
# 2018-10-10  226.350006  1858.560059  157.690002  1132.170044  111.500000
# 2018-10-11  219.500000  1755.400024  154.809998  1106.400024  108.930000
# 2018-10-12  222.880005  1808.949951  156.889999  1115.000000  111.239998
#
# Attributes         Low                                                    ...  \
# Symbols           AAPL         AMZN          FB         GOOG        MSFT  ...
# Date                                                                      ...
# 2018-10-08  220.199997  1830.660034  154.389999  1127.364014  109.339996  ...
# 2018-10-09  222.250000  1852.319946  157.419998  1137.572021  110.800003  ...
# ...

# %%
data.describe()
# Out:
# Attributes        High                                                    \
# Symbols           AAPL         AMZN          FB         GOOG        MSFT
# count       251.000000   251.000000  251.000000   251.000000  251.000000
# mean        194.030678  1777.444779  171.782789  1143.921224  121.872271
# std          20.917806   126.675973   20.129972    63.067313   13.461973
# min         145.720001  1396.030029  129.740005  1003.539978   97.970001
# 25%         175.934998  1675.885010  153.570000  1092.674988  108.859997
# 50%         198.850006  1795.050049  175.050003  1141.699951  120.430000
# 75%         209.195000  1866.390015  187.879997  1196.820007  136.604996
# max         229.929993  2035.800049  208.660004  1289.270020  142.369995
#
# Attributes         Low                                                    ...  \
# Symbols           AAPL         AMZN          FB         GOOG        MSFT  ...
# count       251.000000   251.000000  251.000000   251.000000  251.000000  ...
# ...

# %%
data['Adj Close']
# Out:
# Symbols           AAPL         AMZN          FB         GOOG        MSFT
# Date
# 2018-10-08  220.350662  1864.420044  157.250000  1148.969971  109.135078
# 2018-10-09  223.403275  1870.319946  157.899994  1138.819946  110.523254
# 2018-10-10  213.053894  1755.250000  151.380005  1081.219971  104.517632
# 2018-10-11  211.173065  1719.359985  153.350006  1079.319946  104.271507
# 2018-10-12  218.716034  1788.609985  153.740005  1110.079956  107.874870
# 2018-10-15  214.038605  1760.949951  153.520004  1092.250000  105.935349
# 2018-10-16  218.755417  1819.959961  158.779999  1121.280029  109.282745
# 2018-10-17  217.810089  1831.729980  159.419998  1115.689941  108.997238
# 2018-10-18  212.719086  1770.719971  154.919998  1087.969971  106.821426
# 2018-10-19  215.958801  1764.030029  154.050003  1096.459961  106.978958
# 2018-10-22  217.278320  1789.300049  154.779999  1101.160034  107.933945
# 2018-10-23  219.326538  1768.699951  154.389999  1103.689941  106.427612
# ...

# %%
data["Adj Close"].plot()

# %%
#define and calculate daily return
data["Adj Close"]
