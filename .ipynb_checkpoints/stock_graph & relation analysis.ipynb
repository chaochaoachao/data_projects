# %%
# Description this predicts the price of "FANNG" stock for a specific day
# using the machine leanring code called Support Vector Regression(SVR) Model
# Tesing data would the last day
# Trainning data would be 


# basic
import numpy as np
import pandas as pd
from pandas import Series, DataFrame 

# get data
import pandas_datareader as pdr

# visual tools
# %pylab inline
import matplotlib.pyplot as plt
import seaborn as sns


# time function
from datetime import datetime

#import machine learning
from sklearn.svm import SVR
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
start = datetime(2019,1,1)
alibaba = pdr.get_data_yahoo('BABA', start=start)
amazon = pdr.get_data_yahoo('AMZN', start=start)

# %%
alibaba.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-01-02  137.748993  133.029999  134.130005  136.699997  16708400
# 2019-01-03  134.869995  129.830002  134.270004  130.600006  19531300
# 2019-01-04  141.080002  133.660004  134.259995  139.750000  22845400
# 2019-01-07  144.080002  139.009995  140.550003  143.100006  17239000
# 2019-01-08  147.550003  142.059998  145.000000  146.789993  16487600
#
#              Adj Close
# Date
# 2019-01-02  136.699997
# 2019-01-03  130.600006
# 2019-01-04  139.750000
# 2019-01-07  143.100006
# 2019-01-08  146.789993

# %%
amazon.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-01-02  1553.359985  1460.930054  1465.199951  1539.130005  7983100
# 2019-01-03  1538.000000  1497.109985  1520.010010  1500.280029  6975600
# 2019-01-04  1594.000000  1518.310059  1530.000000  1575.390015  9182600
# 2019-01-07  1634.560059  1589.189941  1602.310059  1629.510010  7993200
# 2019-01-08  1676.609985  1616.609985  1664.689941  1656.579956  8881400
#
#               Adj Close
# Date
# 2019-01-02  1539.130005
# 2019-01-03  1500.280029
# 2019-01-04  1575.390015
# 2019-01-07  1629.510010
# 2019-01-08  1656.579956

# %%
alibaba['Adj Close'].plot()

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
sns.set()

# %%
alibaba['Adj Close'].plot(legend = True, label='ali')
plt.ylabel('Adj Close')
amazon['Adj Close'].plot(legend = True, label='amz')

# %%
alibaba['Volume'].plot(legend = True, label='Ali')
amazon['Volume'].plot(legend = True, label='Amz')

# %%
alibaba['High-Low']=alibaba['High']-alibaba['Low']
amazon['High-Low']=amazon['High']-amazon['Low']

# %%
alibaba['High-Low'].plot()
amazon['High-Low'].plot()

# %%
alibaba['daily return'] = alibaba['Adj Close'].pct_change()
alibaba['daily return'].plot(figsize=(10,4), linestyle='--',marker='o')

# %%
alibaba['daily return'].head()
# Out:
# Date
# 2019-01-02         NaN
# 2019-01-03   -0.044623
# 2019-01-04    0.070061
# 2019-01-07    0.023971
# 2019-01-08    0.025786
# Name: daily return, dtype: float64

# %%
plt.subplot(121)
alibaba['daily return'].plot(kind='hist') 
plt.subplot(122)
alibaba['daily return'].plot(kind='kde')

# %%
sns.distplot(alibaba['daily return'].dropna(),bins=100,color='purple')

# %% [markdown]
# # relationship analysis

# %%
start =datetime(2019,1,1)
company = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'FB']

# %%
top_df = pdr.get_data_yahoo(company,start = start)

# %%
type(top_df)
# Out:
# pandas.core.frame.DataFrame

# %%
top_df['Adj Close']
# Out:
# Symbols           AAPL         AMZN          FB         GOOG        MSFT
# Date
# 2019-01-02  156.049484  1539.130005  135.679993  1045.849976   99.985695
# 2019-01-03  140.505798  1500.280029  131.740005  1016.059998   96.307419
# 2019-01-04  146.503891  1575.390015  137.949997  1070.709961  100.786606
# 2019-01-07  146.177811  1629.510010  138.050003  1068.390015  100.915146
# 2019-01-08  148.964386  1656.579956  142.529999  1076.280029  101.646843
# 2019-01-09  151.494064  1659.420044  144.229996  1074.660034  103.100357
# 2019-01-10  151.978271  1656.219971  144.199997  1070.329956  102.437866
# 2019-01-11  150.486160  1640.560059  143.800003  1057.189941  101.646843
# 2019-01-14  148.223282  1617.209961  145.389999  1044.689941  100.905266
# 2019-01-15  151.256927  1674.560059  148.949997  1077.150024  103.832062
# 2019-01-16  153.104782  1683.780029  147.539993  1080.969971  104.197899
# 2019-01-17  154.013885  1693.219971  148.300003  1089.900024  104.929604
# ...

# %%
top_df = top_df['Adj Close']

# %%
top_df.head()
# Out:
# Symbols           AAPL         AMZN          FB         GOOG        MSFT
# Date
# 2019-01-02  156.049484  1539.130005  135.679993  1045.849976   99.985695
# 2019-01-03  140.505798  1500.280029  131.740005  1016.059998   96.307419
# 2019-01-04  146.503891  1575.390015  137.949997  1070.709961  100.786606
# 2019-01-07  146.177811  1629.510010  138.050003  1068.390015  100.915146
# 2019-01-08  148.964386  1656.579956  142.529999  1076.280029  101.646843

# %%
top_df_dr = top_df.pct_change()

# %%
top_df.plot()

# %%
top_df_dr.plot()

# %%
sns.jointplot('AMZN','GOOG',top_df_dr,kind='scatter')

# %%
sns.pairplot(top_df_dr.dropna())

# %%
# Create theX and y data set, all data are collected expect the last row
# dates = []

#df_amazon_test= amazon.head(len(amazon)-1)
#df_amazon_test.head(5)

dates = []
prices = []

df= amazon.head(len(amazon)-1)
#Reset date as an index
df.reset_index('Date', inplace=True,drop=False)
#Get all of rows for date and close column
df_Close = df.loc[:,"Close"]
df_dates = df.loc[:,"Date"]
df_dates
# Out:
# 0     2019-01-02
# 1     2019-01-03
# 2     2019-01-04
# 3     2019-01-07
# 4     2019-01-08
# 5     2019-01-09
# 6     2019-01-10
# 7     2019-01-11
# 8     2019-01-14
# 9     2019-01-15
# 10    2019-01-16
# 11    2019-01-17
# 12    2019-01-18
# 13    2019-01-22
# 14    2019-01-23
# 15    2019-01-24
# 16    2019-01-25
# 17    2019-01-28
# 18    2019-01-29
# 19    2019-01-30
# 20    2019-01-31
# 21    2019-02-01
# 22    2019-02-04
# 23    2019-02-05
# 24    2019-02-06
# 25    2019-02-07
# 26    2019-02-08
# 27    2019-02-11
# 28    2019-02-12
# 29    2019-02-13
#          ...
# 152   2019-08-09
# 153   2019-08-12
# 154   2019-08-13
# 155   2019-08-14
# 156   2019-08-15
# 157   2019-08-16
# 158   2019-08-19
# 159   2019-08-20
# 160   2019-08-21
# 161   2019-08-22
# 162   2019-08-23
# 163   2019-08-26
# 164   2019-08-27
# 165   2019-08-28
# 166   2019-08-29
# 167   2019-08-30
# 168   2019-09-03
# 169   2019-09-04
# 170   2019-09-05
# 171   2019-09-06
# 172   2019-09-09
# ...

# %%
#convert datetime to oject
df_dates_2 = df_dates.apply(lambda x: x.strftime('%Y-%m-%d'))

print(df_dates_2.head())



#for date in df_dates:
    #dates.append([int(date.str.split('-')[2])])
#    dates.apply(lambda x: x.strftime('%Y-%m-%d'))
#for open_price in df.Close:
#    prices.append(float(open_price))
# Out:
# 0    2019-01-02
# 1    2019-01-03
# 2    2019-01-04
# 3    2019-01-07
# 4    2019-01-08
# Name: Date, dtype: object

# %%
date_day = []

for date in df_dates_2:
    date_day.append(date.split('-')[2])

print (date_day)
    #date_day.append([int(date.str.split('-')[2])])
# Out:
# ['02', '03', '04', '07', '08', '09', '10', '11', '14', '15', '16', '17', '18', '22', '23', '24', '25', '28', '29', '30', '31', '01', '04', '05', '06', '07', '08', '11', '12', '13', '14', '15', '19', '20', '21', '22', '25', '26', '27', '28', '01', '04', '05', '06', '07', '08', '11', '12', '13', '14', '15', '18', '19', '20', '21', '22', '25', '26', '27', '28', '29', '01', '02', '03', '04', '05', '08', '09', '10', '11', '12', '15', '16', '17', '18', '22', '23', '24', '25', '26', '29', '30', '01', '02', '03', '06', '07', '08', '09', '10', '13', '14', '15', '16', '17', '20', '21', '22', '23', '24', '28', '29', '30', '31', '03', '04', '05', '06', '07', '10', '11', '12', '13', '14', '17', '18', '19', '20', '21', '24', '25', '26', '27', '28', '01', '02', '03', '05', '08', '09', '10', '11', '12', '15', '16', '17', '18', '19', '22', '23', '24', '25', '26', '29', '30', '31', '01', '02', '05', '06', '07', '08', '09', '12', '13', '14', '15', '16', '19', '20', '21', '22', '23', '26', '27', '28', '
# ...

# %%
#for open_price in df.Close:
#  prices.append(float(close_price))
#  print (prices)
# Out:
# [1539.1300048828125, 1500.280029296875, 1575.3900146484375, 1629.510009765625, 1656.5799560546875, 1659.4200439453125, 1656.219970703125, 1640.56005859375, 1617.2099609375, 1674.56005859375, 1683.780029296875, 1693.219970703125, 1696.199951171875, 1632.1700439453125, 1640.02001953125, 1654.9300537109375, 1670.5699462890625, 1637.8900146484375, 1593.8800048828125, 1670.4300537109375, 1718.72998046875, 1626.22998046875, 1633.31005859375, 1658.81005859375, 1640.260009765625, 1614.3699951171875, 1588.219970703125, 1591.0, 1638.010009765625, 1640.0, 1622.6500244140625, 1607.949951171875, 1627.5799560546875, 1622.0999755859375, 1619.43994140625, 1631.56005859375, 1633.0, 1636.4000244140625, 1641.0899658203125, 1639.8299560546875, 1671.72998046875, 1696.1700439453125, 1692.4300537109375, 1668.949951171875, 1625.949951171875, 1620.800048828125, 1670.6199951171875, 1673.0999755859375, 1690.81005859375, 1686.219970703125, 1712.3599853515625, 1742.1500244140625, 1761.8499755859375, 1797.2700195
# ...

# %%
df_dates = df_amazon_test.loc[:,'Date']   # get all of the rows from the date column
df_close = df_amazon_test.loc[:,'Close']   # get all of the rows from the Close column

# %%
amazon.tail(1)
